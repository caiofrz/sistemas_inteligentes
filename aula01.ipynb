# %% [markdown]
# <a href="https://colab.research.google.com/github/caiofrz/sistemas_inteligentes/blob/main/aula01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aula 01 - Bibliotecas Numpy e Pandas

# %%
import numpy as np

np.__version__
# Out:
# '1.23.5'

# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
serie_numerica = pd.Series([10,20,15,18,np.nan, 3], dtype=str)
print(serie_numerica)
# Out:
# 0     10
# 1     20
# 2     15
# 3     18
# 4    NaN
# 5      3
# dtype: object

# %%
print(np.isnan(np.nan))
print(np.isnan(54))
# Out:
# True
# False

# %%
print(serie_numerica.values)
print(serie_numerica.index)
# Out:
# ['10' '20' '15' '18' nan '3']
# RangeIndex(start=0, stop=6, step=1)

# %%
serie_numerica[2]
# Out:
# '15'

# %%
dados= pd.Series(data=[7,8,5,4,3,2], index=["A", "B", "C", "D", "E", "F"])
print(dados)
print("-------------------------------")
print(dados["C"])
print("-------------------------------")
print(dados["A":"C"])
# Out:
# A    7
# B    8
# C    5
# D    4
# E    3
# F    2
# dtype: int64
# -------------------------------
# 5
# -------------------------------
# A    7
# B    8
# C    5
# dtype: int64

# %%
dicionario = {
"A": 1,
"B": 3,
"C": 27,
"D": 80
}

dados = pd.Series(dicionario)
dados
# Out:
# A     1
# B     3
# C    27
# D    80
# dtype: int64

# %%
dicionario_populacao = {
'São Paulo': 12000000,
'Rio de Janeiro': 3000000,
'Salvador': 280000000,
'Fortaleza': 260000000,
'Belo Horizonte': 25000000
}

dicionario = pd.Series(dicionario_populacao)
dicionario
# Out:
# São Paulo          12000000
# Rio de Janeiro      3000000
# Salvador          280000000
# Fortaleza         260000000
# Belo Horizonte     25000000
# dtype: int64

# %%
dicionario_funcionarios ={
'Nome': ['João', 'Carlos', 'Júlia', 'Clara', 'Mateus'],
'Salário': [1200,1700,1700, 2000, 1750],
'QuantidadeFilhos': [0, 2, 1, 0, 3]
}
df_funcionarios = pd.DataFrame(dicionario_funcionarios)
df_funcionarios
# Out:
#      Nome  Salário  QuantidadeFilhos
# 0    João   1200.0                 0
# 1  Carlos   1700.0                 2
# 2   Júlia   1700.0                 1
# 3   Clara   2000.0                 0
# 4  Mateus   1750.0                 3
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_funcionarios['Salário'].plot(kind='hist', bins=20, title='Salário')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_funcionarios['QuantidadeFilhos'].plot(kind='hist', bins=20, title='QuantidadeFilhos')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# ...

# %%
from matplotlib import pyplot as plt
df_funcionarios['QuantidadeFilhos'].plot(kind='line', figsize=(8, 4), title='Filhos')
plt.gca().spines[['top', 'right']].set_visible(False)
